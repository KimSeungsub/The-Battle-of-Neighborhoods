# %% [markdown]
# # The Battle of Neighborhoods in Downtown Toronto

# %% [markdown]
# ## Data description

# %% [markdown]
# data link : https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# We use this dataset about consisting of latitude and longitude from wikipedia for Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ## Foursquare API Data

# %% [markdown]
# The information obtained for these items
# 1. Neighborhood
# 2. Neighborhood Latitude
# 3. Neighborhood Longitude
# 4. Venue
# 5. Name of a
